# %% [markdown]
# # https://github.com/byeasmin/30_days_of_python

# %% [markdown]
# # Method of Set

# %%
s1 = {1, 2, 3, 4}

# %%
s2 = {1, 4, 'a', 'b'}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {1, 4, 'a', 'b'}

# %%
s3 = frozenset(s2)

# %%
s3
# Out:
# frozenset({1, 4, 'a', 'b'})

# %%
from IPython.display import Image
Image('method_of_set.png')

# %% [markdown]
# # add()

# %%
s1 = {1, 2, 3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.add('d')

# %%
s1
# Out:
# {1, 2, 3, 4, 'd'}

# %% [markdown]
# # remove()

# %%
s2 = s1

# %%
s2
# Out:
# {1, 2, 3, 4, 'd'}

# %%
s1
# Out:
# {1, 2, 3, 4, 'd'}

# %%
s2.remove('d') # deleted from both s1 and s2

# %%
s2
# Out:
# {1, 2, 3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # copy()

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s4 = s1.copy()

# %%
s4
# Out:
# {1, 2, 3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s4.remove(1)

# %%
s4
# Out:
# {2, 3, 4}

# %%
s1    # so, not deleted from both
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # clear()

# %%
s4.clear()

# %%
s4
# Out:
# set()

# %% [markdown]
# # difference()

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s3
# Out:
# frozenset({1, 4, 'a', 'b'})

# %%
s1.difference(s3)
# Out:
# {2, 3}

# %%
s3.difference(s1)
# Out:
# frozenset({'a', 'b'})

# %% [markdown]
# # difference_update()

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s3
# Out:
# frozenset({1, 4, 'a', 'b'})

# %%
s5 = {1, 2, 3, 4, 6, 8, 9}

# %%
s5
# Out:
# {1, 2, 3, 4, 6, 8, 9}

# %%
s1.difference(s5)
# Out:
# set()

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.add(10)

# %%
s1
# Out:
# {1, 2, 3, 4, 10}

# %%
s1.difference(s5)
# Out:
# {10}

# %%
s1
# Out:
# {1, 2, 3, 4, 10}

# %%
s5
# Out:
# {1, 2, 3, 4, 6, 8, 9}

# %%
s1.difference_update(s5)

# %%
s1
# Out:
# {10}

# %%
# that means that after updating and substructing,
# the result will come, otherwise, the tie will remain even 
# after substructing.

# %% [markdown]
# # issubset()

# %%
s1
# Out:
# {10}

# %%
s2
# Out:
# {10}

# %%
s3
# Out:
# frozenset({1, 4, 'a', 'b'})

# %%
s4
# Out:
# set()

# %%
s5
# Out:
# {1, 2, 3, 4, 6, 8, 9}

# %%
s1.issubset(s3)
# Out:
# False

# %%
s1.issubset(s5)
# Out:
# False

# %%
s3.issubset(s5)
# Out:
# False

# %%
s7 = {1, 2, 3, 4, 5}
s8 = {2, 3, 4}

# %%
s8.issubset(s7)
# Out:
# True

# %%
{2}.issubset(s8)
# Out:
# True

# %% [markdown]
# # issuperset()

# %%
s8.issuperset(s7)
# Out:
# False

# %%
s7.issuperset(s8)
# Out:
# True

# %% [markdown]
# # Symmantic_difference()

# %%
s9 = {1, 2, 7, 8}

# %%
s10 = {1, 2, 4, 5}

# %%
s9
# Out:
# {1, 2, 7, 8}

# %%
s10
# Out:
# {1, 2, 4, 5}

# %%
s9.symmetric_difference(s10)
# Out:
# {4, 5, 7, 8}

# %%
s10.symmetric_difference(s9)
# Out:
# {4, 5, 7, 8}

# %% [markdown]
# # Symmantic_difference()

# %%
s9
# Out:
# {1, 2, 7, 8}

# %%
s10
# Out:
# {1, 2, 4, 5}

# %%
s9.symmetric_difference_update(s10)

# %%
s9
# Out:
# {4, 5, 7, 8}
