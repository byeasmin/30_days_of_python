# %% [markdown]
# # https://github.com/byeasmin/30_days_of_python

# %% [markdown]
# ## Make your own YouTube Downloader

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from pytube import YouTube

# %%
url = 'https://youtu.be/TwusptQpI6Q?list=PLKdU0fuY4OFcot0zyVbM1-zKf_eCUK4zQ'
yt = YouTube(url)

# %%
stream = yt.streams.get_highest_resolution()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 stream = yt.streams.get_highest_resolution()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:157, in YouTube.streaming_data(self)
#     154 @property
#     155 def streaming_data(self):
#     156     """Return streamingData from video info."""
# --> 157     if 'streamingData' in self.vid_info:
#     158         return self.vid_info['streamingData']
#     159     else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:246, in YouTube.vid_info(self)
#     242     return self._vid_info
#     244 innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
# --> 246 innertube_response = innertube.player(self.video_id)
#     247 self._vid_info = innertube_response
#     248 return self._vid_info
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:448, in InnerTube.player(self, video_id)
#     444 query = {
#     445     'videoId': video_id,
#     446 }
#     447 query.update(self.base_params)
# --> 448 return self._call_api(endpoint, query, self.base_data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:390, in InnerTube._call_api(self, endpoint, query, data)
#     386         headers['Authorization'] = f'Bearer {self.access_token}'
#     388 headers.update(self.header)
# --> 390 response = request._execute_request(
#     391     endpoint_url,
#     392     'POST',
#     393     headers=headers,
#     394     data=data
#     395 )
#     396 return json.loads(response.read())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request

# %%
stream.download()
print('Download Completed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 stream.download()
#       2 print('Download Completed')
#
# NameError: name 'stream' is not defined

# %%
stream = yt.streams.filter(progressive = True, res = '720p').first()

if stream:
    stream.download()
    print('Download Completed')
else:
    print('720p not available')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stream = yt.streams.filter(progressive = True, res = '720p').first()
#       3 if stream:
#       4     stream.download()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:157, in YouTube.streaming_data(self)
#     154 @property
#     155 def streaming_data(self):
#     156     """Return streamingData from video info."""
# --> 157     if 'streamingData' in self.vid_info:
#     158         return self.vid_info['streamingData']
#     159     else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:246, in YouTube.vid_info(self)
#     242     return self._vid_info
#     244 innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
# --> 246 innertube_response = innertube.player(self.video_id)
#     247 self._vid_info = innertube_response
#     248 return self._vid_info
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:448, in InnerTube.player(self, video_id)
#     444 query = {
#     445     'videoId': video_id,
#     446 }
#     447 query.update(self.base_params)
# --> 448 return self._call_api(endpoint, query, self.base_data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:390, in InnerTube._call_api(self, endpoint, query, data)
#     386         headers['Authorization'] = f'Bearer {self.access_token}'
#     388 headers.update(self.header)
# --> 390 response = request._execute_request(
#     391     endpoint_url,
#     392     'POST',
#     393     headers=headers,
#     394     data=data
#     395 )
#     396 return json.loads(response.read())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request

# %%
pip uninstall pytube -y
# Out:
# Found existing installation: pytube 15.0.0
# Uninstalling pytube-15.0.0:
#   Successfully uninstalled pytube-15.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/pytube/pytube
# Out:
# Collecting git+https://github.com/pytube/pytube
#   Cloning https://github.com/pytube/pytube to c:\users\asus\appdata\local\temp\pip-req-build-cszqjmqp
#   Resolved https://github.com/pytube/pytube to commit a32fff39058a6f7e5e59ecd06a7467b71197ce35
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: pytube
#   Building wheel for pytube (pyproject.toml): started
#   Building wheel for pytube (pyproject.toml): finished with status 'done'
#   Created wheel for pytube: filename=pytube-15.0.0-py3-none-any.whl size=58128 sha256=5a25cc416de6eed16a9cf243ddc04d8e8138f81589ff25f0be6747f928ced367
#   Stored in directory: C:\Users\ASUS\AppData\Local\Temp\pip-ephem-wheel-cache-z0laslii\wheels\58\3f\0a\36f5d4b6e63c739b68b7efdce433bed6747cd651e365dc4bd4
# Successfully built pytube
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/pytube/pytube 'C:\Users\ASUS\AppData\Local\Temp\pip-req-build-cszqjmqp'

# %%
from pytube import YouTube

# %%
url = "https://youtu.be/JjpfJNC8XiA"   
yt = YouTube(url)

# %%
for stream in yt.streams.filter(progressive=True, file_extension='mp4'):
    print(stream)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for stream in yt.streams.filter(progressive=True, file_extension='mp4'):
#       2     print(stream)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:157, in YouTube.streaming_data(self)
#     154 @property
#     155 def streaming_data(self):
#     156     """Return streamingData from video info."""
# --> 157     if 'streamingData' in self.vid_info:
#     158         return self.vid_info['streamingData']
#     159     else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:246, in YouTube.vid_info(self)
#     242     return self._vid_info
#     244 innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
# --> 246 innertube_response = innertube.player(self.video_id)
#     247 self._vid_info = innertube_response
#     248 return self._vid_info
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:448, in InnerTube.player(self, video_id)
#     444 query = {
#     445     'videoId': video_id,
#     446 }
#     447 query.update(self.base_params)
# --> 448 return self._call_api(endpoint, query, self.base_data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:390, in InnerTube._call_api(self, endpoint, query, data)
#     386         headers['Authorization'] = f'Bearer {self.access_token}'
#     388 headers.update(self.header)
# --> 390 response = request._execute_request(
#     391     endpoint_url,
#     392     'POST',
#     393     headers=headers,
#     394     data=data
#     395 )
#     396 return json.loads(response.read())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request

# %%
stream = yt.streams.filter(progressive=True, res="720p").first()
if stream:
    stream.download()
else:
    print("720p stream not available, try another resolution.")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 stream = yt.streams.filter(progressive=True, res="720p").first()
#       2 if stream:
#       3     stream.download()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:157, in YouTube.streaming_data(self)
#     154 @property
#     155 def streaming_data(self):
#     156     """Return streamingData from video info."""
# --> 157     if 'streamingData' in self.vid_info:
#     158         return self.vid_info['streamingData']
#     159     else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\__main__.py:246, in YouTube.vid_info(self)
#     242     return self._vid_info
#     244 innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
# --> 246 innertube_response = innertube.player(self.video_id)
#     247 self._vid_info = innertube_response
#     248 return self._vid_info
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:448, in InnerTube.player(self, video_id)
#     444 query = {
#     445     'videoId': video_id,
#     446 }
#     447 query.update(self.base_params)
# --> 448 return self._call_api(endpoint, query, self.base_data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\innertube.py:390, in InnerTube._call_api(self, endpoint, query, data)
#     386         headers['Authorization'] = f'Bearer {self.access_token}'
#     388 headers.update(self.header)
# --> 390 response = request._execute_request(
#     391     endpoint_url,
#     392     'POST',
#     393     headers=headers,
#     394     data=data
#     395 )
#     396 return json.loads(response.read())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytube\request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request

# %%
pip uninstall pytube -y
# Out:
# Found existing installation: pytube 15.0.0
# Uninstalling pytube-15.0.0:
#   Successfully uninstalled pytube-15.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/pytube/pytube
# Out:
# Collecting git+https://github.com/pytube/pytube
#   Cloning https://github.com/pytube/pytube to c:\users\asus\appdata\local\temp\pip-req-build-7spu84qz
#   Resolved https://github.com/pytube/pytube to commit a32fff39058a6f7e5e59ecd06a7467b71197ce35
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: pytube
#   Building wheel for pytube (pyproject.toml): started
#   Building wheel for pytube (pyproject.toml): finished with status 'done'
#   Created wheel for pytube: filename=pytube-15.0.0-py3-none-any.whl size=58128 sha256=b987f99f29a7828c2ae4ce5514b6f10fcb1446a7139abffb0a64d20368f0b8c6
#   Stored in directory: C:\Users\ASUS\AppData\Local\Temp\pip-ephem-wheel-cache-9gtq3tur\wheels\58\3f\0a\36f5d4b6e63c739b68b7efdce433bed6747cd651e365dc4bd4
# Successfully built pytube
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/pytube/pytube 'C:\Users\ASUS\AppData\Local\Temp\pip-req-build-7spu84qz'

# %%
from pytube import YouTube

url = "https://youtu.be/JjpfJNC8XiA"
try:
    yt = YouTube(url)
    stream = yt.streams.filter(progressive=True, res="720p").first()
    if stream:
        stream.download()
    else:
        print("720p stream not available.")
except Exception as e:
    print("Download failed:", e)
# Out:
# Download failed: HTTP Error 400: Bad Request

# %%
pip install yt-dlp
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.8.27-py3-none-any.whl.metadata (175 kB)
# Downloading yt_dlp-2025.8.27-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.3 MB 1.1 MB/s eta 0:00:03
#    ------ --------------------------------- 0.5/3.3 MB 1.1 MB/s eta 0:00:03
#    ------------ --------------------------- 1.0/3.3 MB 1.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.3/3.3 MB 1.2 MB/s eta 0:00:02
#    ------------------- -------------------- 1.6/3.3 MB 1.2 MB/s eta 0:00:02
#    ------------------- -------------------- 1.6/3.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.8/3.3 MB 1.1 MB/s eta 0:00:02
#    ------------------------- -------------- 2.1/3.3 MB 1.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 2.4/3.3 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.6/3.3 MB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.9/3.3 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 3.1/3.3 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 1.1 MB/s  0:00:03
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.8.27
# Note: you may need to restart the kernel to use updated packages.

# %%
import yt_dlp

url = "https://youtu.be/JjpfJNC8XiA"

ydl_opts = {
    "format": "bestvideo[height<=720]+bestaudio/best[height<=720]",
    "merge_output_format": "mp4",
    "outtmpl": "%(title)s.%(ext)s"
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://youtu.be/JjpfJNC8XiA
# [youtube] JjpfJNC8XiA: Downloading webpage
# [youtube] JjpfJNC8XiA: Downloading tv simply player API JSON
# [youtube] JjpfJNC8XiA: Downloading tv client config
# [youtube] JjpfJNC8XiA: Downloading player 6742b2b9-main
# [youtube] JjpfJNC8XiA: Downloading tv player API JSON
# [info] JjpfJNC8XiA: Downloading 1 format(s): 398+251
# ERROR: You have requested merging of multiple formats but ffmpeg is not installed. Aborting due to --abort-on-error
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# Cell In[1], line 12
#       5 ydl_opts = {
#       6     "format": "bestvideo[height<=720]+bestaudio/best[height<=720]",
#       7     "merge_output_format": "mp4",
#       8     "outtmpl": "%(title)s.%(ext)s"
#       9 }
#      11 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 12     ydl.download([url])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:3660, in YoutubeDL.download(self, url_list)
#    3657     raise SameFileError(outtmpl)
#    3659 for url in url_list:
# -> 3660     self.__download_wrapper(self.extract_info)(
#    3661         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3663 return self._download_retcode
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:3633, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3630 @functools.wraps(func)
#    3631 def wrapper(*args, **kwargs):
#    3632     try:
# -> 3633         res = func(*args, **kwargs)
#    3634     except CookieLoadError:
#    3635         raise
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:1657, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1655             raise ExistingVideoReached
#    1656         break
# -> 1657     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1658 else:
#    1659     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:1668, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1666 while True:
#    1667     try:
# -> 1668         return func(self, *args, **kwargs)
#    1669     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1670         raise
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:1824, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1822 if process:
#    1823     self._wait_for_video(ie_result)
# -> 1824     return self.process_ie_result(ie_result, download, extra_info)
#    1825 else:
#    1826     return ie_result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:1883, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1881 if result_type == 'video':
#    1882     self.add_extra_info(ie_result, extra_info)
# -> 1883     ie_result = self.process_video_result(ie_result, download=download)
#    1884     self._raise_pending_errors(ie_result)
#    1885     additional_urls = (ie_result or {}).get('additional_urls')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:3065, in YoutubeDL.process_video_result(self, info_dict, download)
#    3063 downloaded_formats.append(new_info)
#    3064 try:
# -> 3065     self.process_info(new_info)
#    3066 except MaxDownloadsReached:
#    3067     max_downloads_reached = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:187, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     184 @functools.wraps(func)
#     185 def wrapper(self, *args, **kwargs):
#     186     try:
# --> 187         return func(self, *args, **kwargs)
#     188     except _UnsafeExtensionError as error:
#     189         self.report_error(
#     190             f'The extracted extension ({error.extension!r}) is unusual '
#     191             'and will be skipped for safety reasons. '
#     192             f'If you believe this is an error{bug_reports_message(",")}')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:3492, in YoutubeDL.process_info(self, info_dict)
#    3490 msg = 'You have requested merging of multiple formats but ffmpeg is not installed'
#    3491 if not self.params.get('ignoreerrors'):
# -> 3492     self.report_error(f'{msg}. Aborting due to --abort-on-error')
#    3493     return
#    3494 self.report_warning(f'{msg}. The formats won\'t be merged')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:1126, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1121 def report_error(self, message, *args, **kwargs):
#    1122     """
#    1123     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1124     in red if stderr is a tty file.
#    1125     """
# -> 1126     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\yt_dlp\YoutubeDL.py:1065, in YoutubeDL.trouble(self, message, tb, is_error)
#    1063     else:
#    1064         exc_info = sys.exc_info()
# -> 1065     raise DownloadError(message, exc_info)
#    1066 self._download_retcode = 1
#
# DownloadError: ERROR: You have requested merging of multiple formats but ffmpeg is not installed. Aborting due to --abort-on-error

# %%
import yt_dlp

url = "https://youtu.be/JjpfJNC8XiA"

ydl_opts = {
    "format": "mp4[height<=720]",  
    "outtmpl": "%(title)s.%(ext)s"
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://youtu.be/JjpfJNC8XiA
# [youtube] JjpfJNC8XiA: Downloading webpage
# [youtube] JjpfJNC8XiA: Downloading tv simply player API JSON
# [youtube] JjpfJNC8XiA: Downloading tv client config
# [youtube] JjpfJNC8XiA: Downloading tv player API JSON
# [info] JjpfJNC8XiA: Downloading 1 format(s): 18
# [download] Sleeping 1.00 seconds as required by the site...
# [download] Destination: Python programming roadmap - what skills should you learn first.mp4
# [download] 100% of   32.24MiB in 00:00:16 at 1.95MiB/s

# %%
pip install yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (2025.8.27)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yt_dlp

url = "https://youtu.be/_titAnLDIF0"

ydl_opts = {
    "format": "mp4[height<=720]",  
    "outtmpl": "%(title)s.%(ext)s"
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://youtu.be/_titAnLDIF0
# [youtube] _titAnLDIF0: Downloading webpage
# [youtube] _titAnLDIF0: Downloading tv simply player API JSON
# [youtube] _titAnLDIF0: Downloading tv client config
# [youtube] _titAnLDIF0: Downloading tv player API JSON
# [info] _titAnLDIF0: Downloading 1 format(s): 18
# [download] Destination: Masha and the Bear 2025 🛵🐯 Learn to Ride a Bike! 🚲🐼 Best episodes cartoon collection 🎬.mp4
# [download] 100% of   95.94MiB in 00:01:02 at 1.53MiB/s
