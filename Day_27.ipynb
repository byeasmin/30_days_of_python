# %% [markdown]
# # https://github.com/byeasmin/30_days_of_python

# %% [markdown]
# # Module

# %% [markdown]
# # Other IDE

# %%
from IPython.display import Image
Image('module_1_no.png')

# %%
from IPython.display import Image
Image('module_2_no.png')

# %%
from IPython.display import Image
Image('module_3_no.png')

# %%
from IPython.display import Image
Image('module_4_no.png')
