# %% [markdown]
# # https://github.com/byeasmin/30_days_of_python

# %% [markdown]
# # Array

# %% [markdown]
# ## Array type

# %%
from IPython.display import Image
Image('array_type.png')

# %% [markdown]
# ## Method of array

# %%
from IPython.display import Image
Image('method_of_array.png')
