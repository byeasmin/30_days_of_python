# %% [markdown]
# # https://github.com/byeasmin/30_days_of_python

# %% [markdown]
# # Conditional Statement

# %% [markdown]
# # if...else

# %%
x = 50
y = 100

if x > y:
    print('x is greater than y')
if y > x:
    print('y is greater than x')
    print('python conditional statement')
else:
    print('out!')
# Out:
# y is greater than x
# python conditional statement

# %% [markdown]
# # if...elif...else

# %%
x = 20
y = 100

if x > y:
    print('x is greater than y')
elif y > x:
    print('y is greater than x')
    print('python conditional statement')
    if x != y:
        print('not equal')
else:
    print('out!')
# Out:
# y is greater than x
# python conditional statement
# not equal

# %%
x = 20
y = 100

if x > y:
    print('x is greater than y')
elif y > x:
    print('y is greater than x')
    print('python conditional statement')
    if x == y:
        print('not equal')
else:
    print('out!')
# Out:
# y is greater than x
# python conditional statement

# %% [markdown]
# # Divisible or not

# %% [markdown]
# # Nested if...elif...else

# %%
num = float(input('Enter a number : '))

if num % 2 == 0:
    if num % 5 == 0:
        print('divisible by 5 and 2')
    else:
        print('No')
else:
    print('no')
# Out:
# Enter a number :  18
# No

# %%
num = float(input('Enter a number : '))

if num % 2 == 0:
    if num % 5 == 0:
        print('divisible by 5 and 2')
    else:
        print('No')
else:
    print('no')
# Out:
# Enter a number :  50
# divisible by 5 and 2

# %%
num = float(input('Enter a number : '))

if num % 2 == 0:
    if num % 5 == 0:
        print('divisible by 5 and 2')
    else:
        print('No')
else:
    print('no')
# Out:
# Enter a number :  13
# no

# %%
num1 = float(input('Enter the number : '))

if num1 % 2 == 0 and num1 % 5 == 0:
    print('num1 is divisible by 2 and 5')
elif num1 % 2 == 0 or num1 % 5 == 0:
    print('num1 is divisible by 2 or 5')
else:
    print('not divisible')
# Out:
# Enter the number :  18
# num1 is divisible by 2 or 5

# %%
num1 = float(input('Enter the number : '))

if num1 % 2 == 0 and num1 % 5 == 0:
    print('num1 is divisible by 2 and 5')
elif num1 % 2 == 0 or num1 % 5 == 0:
    print('num1 is divisible by 2 or 5')
else:
    print('not divisible')
# Out:
# Enter the number :  50
# num1 is divisible by 2 and 5

# %%
num1 = float(input('Enter the number : '))

if num1 % 2 == 0 and num1 % 5 == 0:
    print('num1 is divisible by 2 and 5')
elif num1 % 2 == 0 or num1 % 5 == 0:
    print('num1 is divisible by 2 or 5')
else:
    print('not divisible')
# Out:
# Enter the number :  11
# not divisible

# %%
from IPython.display import Image
Image(r'C:\Users\ASUS\OneDrive\画像\Screenshots\Screenshot 2025-08-13 232509.png')
#Image('electricity.png') - if i had saved in this folder

# %%
# solution

# %%
 amount = 0

net_units = float(input('Enter the unit value : '))

if net_units <= 100:
    amount = 0
    print('amount is ', amount)
elif net_units > 100 and net_units <= 200:
    amount = ((net_units - 100) * 5)
    print('amount is ', amount)
elif net_units > 200:
    amount = ((net_units - 200) * 10) + 500
    print('amount is ', amount)
# Out:
# Enter the unit value :  350
# amount is  2000.0

# %%
 amount = 0

net_units = float(input('Enter the unit value : '))

if net_units <= 100:
    amount = 0
elif net_units > 100 and net_units <= 200:
    amount = ((net_units - 100) * 5)
elif net_units > 200:
    amount = ((net_units - 200) * 10) + 500
print('amount is ', amount)
# Out:
# Enter the unit value :  350
# amount is  2000.0

# %%
 amount = 0

net_units = float(input('Enter the unit value : '))

if net_units <= 100:
    amount = 0
elif net_units > 100 and net_units <= 200:
    amount = ((net_units - 100) * 5)
elif net_units > 200:
    amount = ((net_units - 200) * 10) + 500
print('amount is ', amount)
# Out:
# Enter the unit value :  100
# amount is  0

# %%
 amount = 0

net_units = float(input('Enter the unit value : '))

if net_units <= 100:
    amount = 0
elif net_units > 100 and net_units <= 200:
    amount = ((net_units - 100) * 5)
elif net_units > 200:
    amount = ((net_units - 200) * 10) + 500
print('amount is ', amount)
# Out:
# Enter the unit value :  150
# amount is  250.0

# %%
a = 'day_4'

print('{} is finished'. format(a))
# Out:
# day_4 is finished
